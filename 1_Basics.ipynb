# %% [markdown]
# # Contents
# - Overview
# - Imports

# %% [markdown]
# # Overview

# %% [markdown]
# # Imports

# %%
# Data Manipulation
import numpy as np
import pandas as pd

# Data Visulaization
import matplotlib.pyplot as plt

# For QQ Plot
import scipy.stats
import pylab

# %% [markdown]
# # Load the Data

# %%
raw_csv_data = pd.read_csv('Index2018.csv')

# %%
df_comp = raw_csv_data.copy()

# %% [markdown]
# # Examine the Data

# %%
df_comp.head()
# Out:
#          Date         spx          dax         ftse        nikkei
# 0  1994-01-07  469.899994  2224.949951  3446.000000  18124.009766
# 1  1994-01-10  475.269989  2225.000000  3440.600098  18443.439453
# 2  1994-01-11  474.130005  2228.100098  3413.800049  18485.250000
# 3  1994-01-12  474.170013  2182.060059  3372.000000  18793.880859
# 4  1994-01-13  472.470001  2142.370117  3360.000000  18577.259766

# %%
df_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6277 entries, 0 to 6276
# Data columns (total 5 columns):
# Date      6277 non-null object
# spx       6277 non-null float64
# dax       6277 non-null float64
# ftse      6277 non-null float64
# nikkei    6277 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 245.3+ KB

# %%
df_comp.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6277.000000   6277.000000  6277.000000   6277.000000
# mean   1288.642527   6083.542234  5423.624055  14597.731724
# std     487.868179   2755.634483  1145.565615   4043.836669
# min     438.920013   1911.699951  2876.600098   7054.979980
# 25%     992.719971   4070.459961  4486.700195  10701.129883
# 50%    1233.760010   5774.259766  5663.299805  15031.599609
# 75%    1460.250000   7445.899902  6304.600098  17860.089844
# max    2872.870117  13559.599609  7778.600098  24124.150391

# %%
df_comp.isna().sum()
# Out:
# Date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %% [markdown]
# # Plot The Data

# %%
df_comp.columns
# Out:
# Index(['Date', 'spx', 'dax', 'ftse', 'nikkei'], dtype='object')

# %%
df_comp['spx'].plot(title="S&P500 Prices", figsize=(20,5))
plt.show()

# %%
df_comp['ftse'].plot(figsize=(20,5), title="FTSE100 Prices")
plt.show()

# %%
df_comp['spx'].plot(title="S&P500 Prices", figsize=(20,5))
df_comp['ftse'].plot(figsize=(20,5), title="FTSE100 Prices")
plt.show()

# %% [markdown]
# # Plot the QQ Plot

# %%
scipy.stats.probplot(df_comp['spx'], plot=pylab)
pylab.show()
